# %% [markdown]
# # Variational formulations: the Poisson equation
#
# $$
# \left\{
# \begin{aligned}
# -\Delta u &= f \ &\text{on }\Omega, \\
# u &= 0 \ &\text{on }\Gamma_D, \\
# \partial_n u &= 0 \ &\text{on }\Gamma_N.
# \end{aligned}
# \right.
# $$
